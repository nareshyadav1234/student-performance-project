# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Student_perfromance_Dataset.csv")
df
# Out:
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female             NaN               18.0
# ..         ...             ...     ...             ...                ...
# 995        NaN  Kenneth Murray    Male            85.0               20.0
# 996     4497.0       Amy Stout  Female            91.0                NaN
# 997     1886.0             NaN    Male            85.0                8.0
# 998     7636.0  Joseph Sherman    Male            88.0               17.0
# 999     8021.0     Maria Walls  Female            88.0               10.0
#
#      PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade  \
# ...

# %%
df.columns
# Out:
# Index(['StudentID', 'Name', 'Gender', 'AttendanceRate', 'StudyHoursPerWeek',
#        'PreviousGrade', 'ExtracurricularActivities', 'ParentalSupport',
#        'FinalGrade', 'Study Hours', 'Attendance (%)', 'Online Classes Taken'],
#       dtype='object')

# %% [markdown]
# **Handling Missing Values**

# %%
df.isnull().sum()
# Out:
# StudentID                    40
# Name                         34
# Gender                       48
# AttendanceRate               40
# StudyHoursPerWeek            50
# PreviousGrade                33
# ExtracurricularActivities    43
# ParentalSupport              22
# FinalGrade                   40
# Study Hours                  24
# Attendance (%)               41
# Online Classes Taken         25
# dtype: int64

# %%
df.ffill(inplace=True)

# %%
df.isnull().sum()
# Out:
# StudentID                    0
# Name                         0
# Gender                       0
# AttendanceRate               0
# StudyHoursPerWeek            0
# PreviousGrade                0
# ExtracurricularActivities    0
# ParentalSupport              0
# FinalGrade                   0
# Study Hours                  0
# Attendance (%)               0
# Online Classes Taken         0
# dtype: int64

# %%
df
# Out:
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            92.0               18.0
# ..         ...             ...     ...             ...                ...
# 995     2787.0  Kenneth Murray    Male            85.0               20.0
# 996     4497.0       Amy Stout  Female            91.0               20.0
# 997     1886.0       Amy Stout    Male            85.0                8.0
# 998     7636.0  Joseph Sherman    Male            88.0               17.0
# 999     8021.0     Maria Walls  Female            88.0               10.0
#
#      PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade  \
# ...

# %% [markdown]
# **Remove duplicate**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female            92.0               18.0
# ..         ...             ...     ...             ...                ...
# 995     2787.0  Kenneth Murray    Male            85.0               20.0
# 996     4497.0       Amy Stout  Female            91.0               20.0
# 997     1886.0       Amy Stout    Male            85.0                8.0
# 998     7636.0  Joseph Sherman    Male            88.0               17.0
# 999     8021.0     Maria Walls  Female            88.0               10.0
#
#      PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade  \
# ...

# %% [markdown]
# **Fix Column Names**

# %%
df.rename(columns={
    'Study Hours': 'StudyHours',
    'Attendance (%)': 'Attendance'
}, inplace=True)

# %% [markdown]
# **Data Type Conversion**

# %%
df['Attendance'] = df['Attendance'].astype(float)
df['StudyHours'] = df['StudyHours'].astype(float)

# %% [markdown]
# **Basic Statistics**

# %%
df.describe()
# Out:
#          StudentID  AttendanceRate  StudyHoursPerWeek  PreviousGrade  \
# count  1000.000000     1000.000000        1000.000000    1000.000000
# mean   5431.852000       85.532000          17.662000      77.651000
# std    2637.192396        7.387662           6.301386      10.010465
# min       1.000000       70.000000           8.000000      60.000000
# 25%    3176.750000       82.000000          12.000000      70.000000
# 50%    5442.000000       88.000000          18.000000      78.000000
# 75%    7734.500000       91.000000          22.000000      86.000000
# max    9998.000000       95.000000          30.000000      90.000000
#
#        ExtracurricularActivities   FinalGrade   StudyHours   Attendance
# count                1000.000000  1000.000000  1000.000000  1000.000000
# mean                    1.521000    80.005000     2.418300    77.167000
# std                     1.044342     9.513226     1.613536    19.099683
# ...

# %% [markdown]
# **Average Values**

# %%
df[['StudyHours','Attendance','FinalGrade']].mean()
# Out:
# StudyHours     2.4183
# Attendance    77.1670
# FinalGrade    80.0050
# dtype: float64

# %% [markdown]
# **Trends & Patterns**

# %%
df.groupby('ParentalSupport')['FinalGrade'].mean()
# Out:
# ParentalSupport
# High      79.521368
# Low       80.185304
# Medium    80.342262
# Name: FinalGrade, dtype: float64

# %% [markdown]
# **Invalid Values Check**

# %%
df[df['Attendance'] > 100]
df[df['StudyHours'] < 0]
# Out:
#      StudentID             Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 74      1470.0   Michelle Jones  Female            95.0               10.0
# 125     3430.0     Jessica Lamb    Male            78.0               18.0
# 148     5059.0  Michaela Powell  Female            85.0               12.0
# 220     8484.0     Alicia Ortiz    Male            82.0               17.0
# 251     3527.0   Michael Foster  Female            95.0               30.0
# 321     3831.0  Jessica Jenkins  Female            92.0               10.0
# 366     4659.0       Jill Kelly  Female            70.0               30.0
# 380     6416.0  Raymond Murillo    Male            85.0               15.0
# 672     8203.0   David Martinez    Male            78.0               30.0
# 798     1378.0       Chad Colon  Female            82.0               17.0
#
#      PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade  \
# ...

# %% [markdown]
# **Unique Values Check**

# %%
df['Gender'].unique()
df['ParentalSupport'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %% [markdown]
# **Outliers Detection**

# %%
plt.boxplot(df['FinalGrade'])
plt.title("Outliers in Final Grade")
plt.show()

# %% [markdown]
# **Average Grade by Gender**

# %%
df.groupby('Gender')['FinalGrade'].mean().plot(kind='bar')
plt.title("Average Grade by Gender")
plt.show()

# %% [markdown]
# **Distribution of Final Grades**

# %%
df['FinalGrade'].hist()
plt.title("Distribution of Final Grades")
plt.show()

# %% [markdown]
# **Study Hours Distribution**

# %%
df['StudyHours'].hist()
plt.show()

# %% [markdown]
# **StudyHours Vs Final Grades**

# %%
plt.scatter(df['StudyHours'], df['FinalGrade'])
plt.xlabel("Study Hours")
plt.ylabel("Final Grade")
plt.show()

# %% [markdown]
# **Attendance vs Final Grade**

# %%
plt.scatter(df['Attendance'], df['FinalGrade'])
plt.xlabel("Attendance")
plt.ylabel("Final Grade")
plt.show()

# %% [markdown]
# **Gender vs Average Grade**

# %%
df.groupby('Gender')['FinalGrade'].mean().plot(kind='bar')
plt.title("Gender vs Grade")
plt.show()

# %% [markdown]
# **Parental Support vs Grade**

# %%
df.groupby('ParentalSupport')['FinalGrade'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# **Online Classes vs Grade**

# %%
df.groupby('Online Classes Taken')['FinalGrade'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# **Correlation Heatmap**

# %%
numeric_df = df.select_dtypes(include=['number'])
numeric_df.corr()
# Out:
#                            StudentID  AttendanceRate  StudyHoursPerWeek  \
# StudentID                   1.000000        0.062960           0.001037
# AttendanceRate              0.062960        1.000000           0.028121
# StudyHoursPerWeek           0.001037        0.028121           1.000000
# PreviousGrade              -0.017682        0.027310          -0.008505
# ExtracurricularActivities  -0.025156       -0.033626           0.024200
# FinalGrade                  0.061913       -0.014566           0.041507
# StudyHours                  0.048496       -0.002682          -0.021621
# Attendance                 -0.020868        0.012969           0.043211
#
#                            PreviousGrade  ExtracurricularActivities  \
# StudentID                      -0.017682                  -0.025156
# AttendanceRate                  0.027310                  -0.033626
# StudyHoursPerWeek              -0.008505                   0.024200
# ...

# %%
sns.heatmap(numeric_df.corr(), annot=True)
plt.show()

# %% [markdown]
# **Model Selection (Linear Regression)**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = df[['StudyHours', 'Attendance']]
y = df['FinalGrade']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# **Train Model**

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Prediction**

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# **Accuracy Check**

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 103.2990309288065

# %%
df.columns
# Out:
# Index(['StudentID', 'Name', 'Gender', 'AttendanceRate', 'StudyHoursPerWeek',
#        'PreviousGrade', 'ExtracurricularActivities', 'ParentalSupport',
#        'FinalGrade', 'StudyHours', 'Attendance', 'Online Classes Taken'],
#       dtype='object')

# %% [markdown]
# **R² Score**

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# -0.005372965275196595
